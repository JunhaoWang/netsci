# %% [markdown]
# # p1 - bonus 1

# %% [markdown]
# # Summaries

# %% [markdown]
# We convert all graphs to simple ones by looking only at upper triangular matrix of the ajacency, and make it symmetric.

# %% [markdown]
# All networks with node size greater than 5000, we use a uniformly random sampled set of nodes to approximate clustering, path, component, degree correlation and degree cluster correlation, but not degree and eigen.

# %% [markdown]
# For eigen distribution, we only plot top 20 largest eigenvalues. And the eigen gap defined in class is computationally infeasible for even small graph. Thus we used the difference between largest and second largest eigen value as eigen gap.

# %% [markdown]
# For BA model, we procedurally generate preferential attachment starting from a fully connected graph. And we don't deal with multiple edges, and allow self loops.

# %% [markdown]
# For bonus 1, we modify the the growth factor m to be growing logithmically to the size of the network.

# %% [markdown]
# # Findings

# %% [markdown]
# Many degree distribution has a curvy tail on the upper left, indicating not as many low degree nodes as BA model suggests, this might be relevant to the latest paper on why log normal might fit real network better than power law.

# %% [markdown]
# BA model approximates degree distribution well, modified BA model creates some outliers for degree distribution, since some nodes have way more added connections that others, thus forming mega hubs.

# %% [markdown]
# For clustering, higher degree nodes tend to have lower clustering. BA model cannot approximate clustering well.

# %% [markdown]
# For path, BA model approximates the shape of the plot well, but not average length well.

# %% [markdown]
# Component analysis is highly biased by subsampling and no good insights can come out.

# %% [markdown]
# Top 20 eigen values normally fall into distinct groups, at least 2.

# %% [markdown]
# Most degree correlation coefficient is positive.

# %% [markdown]
# And degree clustering correlation is negative, as observed in clustering plot.

# %% [markdown]
# # Plots

# %% [markdown]
# ## collaboration

# %%
datas = [
    ('collaboration', 'datasets/collaboration_in.npz'),
    ('citation', 'datasets/citation_in.npz'),
    ('actor', 'datasets/actor_in.npz'),
    ('email', 'datasets/email_in.npz'),
    ('internet', 'datasets/internet_in.npz'),
    ('metabolic', 'datasets/metabolic_in.npz'),
    ('phonecalls', 'datasets/phonecalls_in.npz'),
    ('powergrid', 'datasets/powergrid_in.npz'),
    ('protein', 'datasets/protein_in.npz'),
    ('www', 'datasets/www_in.npz')
]
metrics = [
    'degree',
    'clustering',
    'path',
    'component',
    'eigen',
    'degreecorr',
    'degreecluster',
]

# %%
for metric in metrics:
    print('# {}'.format(metric))
    for data in datas:
        data = data[0]
        print('## {}'.format(data))
        for mod in ['', 'ba_', 'mod_ba_']:
            if mod == '':
                print('### {}'.format('original network'))
            elif mod == 'ba_':
                print('### {}'.format('BA network'))
            else:
                print('### {}'.format('modified BA network'))
            print('![title](results/{}_{}.png)'.format(mod + data, metric))
            print('\n')
# Out:
# # degree
# ## collaboration
# ### original network
# ![title](results/collaboration_degree.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_degree.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_degree.png)
#
#
# ### BA network
# ![title](results/ba_citation_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_degree.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_degree.png)
#
#
# ### BA network
# ![title](results/ba_actor_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_degree.png)
#
#
# ## email
# ### original network
# ![title](results/email_degree.png)
#
#
# ### BA network
# ![title](results/ba_email_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_degree.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_degree.png)
#
#
# ### BA network
# ...

# %% [markdown]
# # degree
# ## collaboration
# ### original network
# ![title](results/collaboration_degree.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_degree.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_degree.png)
#
#
# ### BA network
# ![title](results/ba_citation_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_degree.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_degree.png)
#
#
# ### BA network
# ![title](results/ba_actor_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_degree.png)
#
#
# ## email
# ### original network
# ![title](results/email_degree.png)
#
#
# ### BA network
# ![title](results/ba_email_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_degree.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_degree.png)
#
#
# ### BA network
# ![title](results/ba_internet_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_degree.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_degree.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_degree.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_degree.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_degree.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_degree.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_degree.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_degree.png)
#
#
# ### BA network
# ![title](results/ba_protein_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_degree.png)
#
#
# ## www
# ### original network
# ![title](results/www_degree.png)
#
#
# ### BA network
# ![title](results/ba_www_degree.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_degree.png)
#
#
# # clustering
# ## collaboration
# ### original network
# ![title](results/collaboration_clustering.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_clustering.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_clustering.png)
#
#
# ### BA network
# ![title](results/ba_citation_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_clustering.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_clustering.png)
#
#
# ### BA network
# ![title](results/ba_actor_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_clustering.png)
#
#
# ## email
# ### original network
# ![title](results/email_clustering.png)
#
#
# ### BA network
# ![title](results/ba_email_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_clustering.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_clustering.png)
#
#
# ### BA network
# ![title](results/ba_internet_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_clustering.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_clustering.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_clustering.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_clustering.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_clustering.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_clustering.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_clustering.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_clustering.png)
#
#
# ### BA network
# ![title](results/ba_protein_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_clustering.png)
#
#
# ## www
# ### original network
# ![title](results/www_clustering.png)
#
#
# ### BA network
# ![title](results/ba_www_clustering.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_clustering.png)
#
#
# # path
# ## collaboration
# ### original network
# ![title](results/collaboration_path.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_path.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_path.png)
#
#
# ### BA network
# ![title](results/ba_citation_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_path.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_path.png)
#
#
# ### BA network
# ![title](results/ba_actor_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_path.png)
#
#
# ## email
# ### original network
# ![title](results/email_path.png)
#
#
# ### BA network
# ![title](results/ba_email_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_path.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_path.png)
#
#
# ### BA network
# ![title](results/ba_internet_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_path.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_path.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_path.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_path.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_path.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_path.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_path.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_path.png)
#
#
# ### BA network
# ![title](results/ba_protein_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_path.png)
#
#
# ## www
# ### original network
# ![title](results/www_path.png)
#
#
# ### BA network
# ![title](results/ba_www_path.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_path.png)
#
#
# # component
# ## collaboration
# ### original network
# ![title](results/collaboration_component.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_component.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_component.png)
#
#
# ### BA network
# ![title](results/ba_citation_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_component.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_component.png)
#
#
# ### BA network
# ![title](results/ba_actor_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_component.png)
#
#
# ## email
# ### original network
# ![title](results/email_component.png)
#
#
# ### BA network
# ![title](results/ba_email_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_component.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_component.png)
#
#
# ### BA network
# ![title](results/ba_internet_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_component.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_component.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_component.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_component.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_component.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_component.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_component.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_component.png)
#
#
# ### BA network
# ![title](results/ba_protein_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_component.png)
#
#
# ## www
# ### original network
# ![title](results/www_component.png)
#
#
# ### BA network
# ![title](results/ba_www_component.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_component.png)
#
#
# # eigen
# ## collaboration
# ### original network
# ![title](results/collaboration_eigen.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_eigen.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_eigen.png)
#
#
# ### BA network
# ![title](results/ba_citation_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_eigen.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_eigen.png)
#
#
# ### BA network
# ![title](results/ba_actor_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_eigen.png)
#
#
# ## email
# ### original network
# ![title](results/email_eigen.png)
#
#
# ### BA network
# ![title](results/ba_email_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_eigen.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_eigen.png)
#
#
# ### BA network
# ![title](results/ba_internet_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_eigen.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_eigen.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_eigen.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_eigen.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_eigen.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_eigen.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_eigen.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_eigen.png)
#
#
# ### BA network
# ![title](results/ba_protein_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_eigen.png)
#
#
# ## www
# ### original network
# ![title](results/www_eigen.png)
#
#
# ### BA network
# ![title](results/ba_www_eigen.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_eigen.png)
#
#
# # degreecorr
# ## collaboration
# ### original network
# ![title](results/collaboration_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_degreecorr.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_citation_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_degreecorr.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_actor_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_degreecorr.png)
#
#
# ## email
# ### original network
# ![title](results/email_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_email_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_degreecorr.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_internet_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_degreecorr.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_degreecorr.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_degreecorr.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_degreecorr.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_protein_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_degreecorr.png)
#
#
# ## www
# ### original network
# ![title](results/www_degreecorr.png)
#
#
# ### BA network
# ![title](results/ba_www_degreecorr.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_degreecorr.png)
#
#
# # degreecluster
# ## collaboration
# ### original network
# ![title](results/collaboration_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_collaboration_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_collaboration_degreecluster.png)
#
#
# ## citation
# ### original network
# ![title](results/citation_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_citation_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_citation_degreecluster.png)
#
#
# ## actor
# ### original network
# ![title](results/actor_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_actor_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_actor_degreecluster.png)
#
#
# ## email
# ### original network
# ![title](results/email_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_email_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_email_degreecluster.png)
#
#
# ## internet
# ### original network
# ![title](results/internet_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_internet_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_internet_degreecluster.png)
#
#
# ## metabolic
# ### original network
# ![title](results/metabolic_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_metabolic_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_metabolic_degreecluster.png)
#
#
# ## phonecalls
# ### original network
# ![title](results/phonecalls_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_phonecalls_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_phonecalls_degreecluster.png)
#
#
# ## powergrid
# ### original network
# ![title](results/powergrid_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_powergrid_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_powergrid_degreecluster.png)
#
#
# ## protein
# ### original network
# ![title](results/protein_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_protein_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_protein_degreecluster.png)
#
#
# ## www
# ### original network
# ![title](results/www_degreecluster.png)
#
#
# ### BA network
# ![title](results/ba_www_degreecluster.png)
#
#
# ### modified BA network
# ![title](results/mod_ba_www_degreecluster.png)
